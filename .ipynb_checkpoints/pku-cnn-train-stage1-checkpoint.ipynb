# %% [markdown]
# - Download Model Weights from https://www.kaggle.com/hypocrites/imageaiweighs
# - (Kernel Notebook > File > Add or Upload Data > Datasets > Search By URL > {Above URL})

# %%
"""
# !pip install imageai --quiet
# !pip install tensorflow==1.14.0 --quiet
# !pip install tensorflow-gpu==1.14.0 --quiet
"""
pass

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

from IPython.display import clear_output
from sklearn import preprocessing

from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# example of converting an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# Out:
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
# %run paths.py # Load all our paths
# %run methods.py # Load all our methods

os.listdir(IMAGEAIWEIGHTS)
# Out:
# ['resnet50_coco_best_v2.0.1.h5', 'yolo.h5', 'imageaiweighs.zip']

# %%
df_train = pd.read_csv(os.path.join(DATASET_DIR, 'train.csv'))

# Append a col specifying # of cars, inspired by seshadrikolluri/vehicle-angle-prediction-understanding-eda
df_train['NumCars'] = [int((x.count(' ')+1)/7) for x in df_train['PredictionString']]

# df_train.head()

# %%
# show_image(imageId=df_train["ImageId"][0],width=12,addMask=True,markCars=df_train["PredictionString"][0])

# %%
detector = detector_imageai('yolo')

keys = np.array(df_train["ImageId"].keys())
np.random.shuffle(keys)

for key in keys:
    
    #key = 3271 # Just to reproduce the result of a random key taken from print below
    print(key)
    
    image = return_img(imageId=df_train["ImageId"][key])
    
    returned_image, detections = predict_using_detector(detector,image)
    ground_truth = df_train["PredictionString"][key]
                
    TP,FP,FN,TP_points = find_sensitivity(ground_truth,detections)
    print("TP",TP,"FP",FP,"FN",FN)
    
    show_image(img=returned_image,width=15,markCars=ground_truth)
    
    break
# Out:
# WARNING:tensorflow:From /home/csgrads/samad028/anaconda3/envs/py37/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2456
# TP 1 FP 0 FN 4

# %%
def analyse_detector_stage(detectorName,df_data=df_train,detection_probability=50,extract=False):
    
    CSI = 0
    avgCSI = 0
    CSI_temp = 0
    anamoly = ""
    
    df = df_data.copy()
    
    df["DetectedCars"] = ""
    df["TP"] = ""
    df["FP"] = ""
    df["FN"] = ""
    df["CSI"] = ""
    
    if extract:
    
        filename = os.path.join(DATASET_DIR , "detections/"+detectorName+"-"+str(detection_probability)+"-detections.csv")    
        detectionsDict = dict()

        """# Open once in w+ mode to clear it
        f = open(filename, "w+")
        f.close()
        newCSV = True"""
        
    detector = detector_imageai(detectorName)
    totalDetectionsRows = len(df.index)
    countDetectedRows = 0
    countCSIRows = 0

    for instance,row in df.iterrows():
        
        imageId = row["ImageId"]
        
        countDetectedRows += 1
        image = return_img(imageId=imageId)
        ground_truth = df["PredictionString"][instance]
        
        if extract:
            
            # IF extract detections
            
            detections, objects_path = detector.detectCustomObjectsFromImage(
                custom_objects=detector.CustomObjects(car=True),
                display_object_name = False,
                input_image=image, 
                input_type="array",
                output_image_path=os.path.join(DETECTIONS_DIR , detectorName+"-"+str(detection_probability)+"/"+imageId+".jpg"),
                minimum_percentage_probability=detection_probability,
                extract_detected_objects=extract)
                
        else:
            
            returned_image, detections = detector.detectCustomObjectsFromImage(
                custom_objects=detector.CustomObjects(car=True),
                display_object_name = False,
                input_image=image, 
                input_type="array",
                output_type="array",
                minimum_percentage_probability=detection_probability,
                extract_detected_objects=extract)
            
            if totalDetectionsRows == 1:
                print("Showing Image, shortly ...")
                show_image(img=returned_image,width=15,markCars=ground_truth)
        

        TP,FP,FN,TP_points = find_sensitivity(ground_truth,detections)
        
        if extract:
            for eachObject, eachObjectPath in zip(detections, objects_path):
                for TP_point in TP_points:
                    if TP_point["box"] == eachObject["box_points"]:

                        eachObjectPath = imageId+"-"+str(eachObjectPath.split("objects/")[1].split(".")[0].split("-")[1])
                        detectionsDict[eachObjectPath] = dict()
                        detectionsDict[eachObjectPath]["Probability"] = eachObject["percentage_probability"]
                        # Idea: Replace the following x,y,z by the inverse of get_image_coords fn for mean x,y from detected bounding boxes
                        # or Better: Feed bounding box coordinates to future neural network along with image
                        detectionsDict[eachObjectPath]["x1"] = TP_point["x1"]
                        detectionsDict[eachObjectPath]["x2"] = TP_point["x2"]
                        detectionsDict[eachObjectPath]["y1"] = TP_point["y1"]
                        detectionsDict[eachObjectPath]["y2"] = TP_point["y2"]

                        original_string = TP_point["original_string"]

                        for param,value in original_string.items():
                            detectionsDict[eachObjectPath][param] = value
                    

        df.loc[instance,"DetectedCars"] = len(detections)
        df.loc[instance,"TP"] = TP
        df.loc[instance,"FP"] = FP
        df.loc[instance,"FN"] = FN
        
        cars_actual = df["NumCars"][instance]
        cars_predicted = len(detections)       
        
        if (TP+FP+FN) > 0: # Don't Check accuracy when there are no cars
            
            CSI_temp = TP / (TP+FP+FN)
            CSI += CSI_temp
            
            countCSIRows += 1            
            avgCSI = CSI / countCSIRows
            
            """if CSI == -1: # No earlier acc set
                CSI = CSI_temp
            CSI = ( CSI_temp + CSI ) / 2"""
            
            df.loc[instance,"CSI"] = round(CSI_temp,3)
            
        elif cars_actual > 0: # This shouldn't occur when cars in actual are more than 0
            anamoly += f"Anamoly detected for ImageID: {imageId}, (TP+FP+FN)=0 when Actual Cars are {cars_actual}\n"
        
        if totalDetectionsRows > 1:
            clear_output(wait=True)
        
        if(anamoly != ""):
            print(anamoly)
        print(f"{countDetectedRows}/{totalDetectionsRows} Results Predicted. Average CSI so far: {round(avgCSI*100,2)}% (Last {round(CSI_temp*100,2)}%)")
        
        # Generate Detections CSV
        
        if extract:
                
            df_det = pd.DataFrame(detectionsDict)
            
            df_det = df_det.T
            """if(newCSV):
                newCSV = False
                header = True
            else:
                header = False

            # open in append mode
            f = open(filename, 'a')
            df_det.to_csv(f, header=header,index_label='ImageId')"""
            
            f = open(filename, 'w+')
            df_det.to_csv(f, header=True,index_label='ImageId')
            f.close()
            
    
    if extract:
        return df, avgCSI, detectionsDict
        
    #df_det = pd.DataFrame(detectionsDict)
    #display(df_det.T)    
    
    return df, avgCSI

# %%
df_yolo, CSI = analyse_detector_stage(detectorName='yolo',df_data=df_train.head(10),detection_probability=50,extract=False)
df_yolo
# Out:
# 10/10 Results Predicted. Average CSI so far: 48.62% (Last 53.85%)
#         ImageId                                   PredictionString  NumCars  \
# 0  ID_8a6e65317  16 0.254839 -2.57534 -3.10256 7.96539 3.20066 ...        5
# 1  ID_337ddc495  66 0.163988 0.192169 -3.12112 -3.17424 6.55331...        8
# 2  ID_a381bf4d0  43 0.162877 0.00519276 -3.02676 2.1876 3.53427...       25
# 3  ID_7c4a3e0aa  43 0.126957 -3.04442 -3.10883 -14.738 24.6389 ...        3
# 4  ID_8b510fad6  37 0.16017 0.00862796 -3.0887 -3.04548 3.4977 ...       19
# 5  ID_679502721  50 0.173958 1.6934 -3.07 17.2953 5.82861 22.82...        3
# 6  ID_f681b269f  70 0.201977 -0.0482845 -3.07942 3.94442 5.6771...        9
# 7  ID_2803cf7b5  8 0.172028 3.1064 -3.10087 -18.0211 4.98543 27...       10
# 8  ID_89449e126  7 0.156087 -0.0318094 -3.06916 2.83965 2.2697 ...        8
# 9  ID_2ad1fc1b3  28 0.1514 0.0071941 -3.10048 2.94173 8.31218 4...       12
#
#    DetectedCars  TP  FP  FN    CSI
# 0             4   4   0   1    0.8
# 1             4   4   0   4    0.5
# 2            12  11   1  14  0.423
# 3             1   1   0   2  0.333
# 4            13  12   1   7    0.6
# 5             3   1   2   2    0.2
# 6             6   5   1   4    0.5
# 7             3   3   0   7    0.3
# 8             7   6   1   2  0.667
# 9             8   7   1   5  0.538

# %%
"""
Anamoly detected for ImageID: ID_408f58e9f, (TP+FP+FN)=0 when Actual Cars are 7
Anamoly detected for ImageID: ID_c44983aeb, (TP+FP+FN)=0 when Actual Cars are 10
Anamoly detected for ImageID: ID_1a5a10365, (TP+FP+FN)=0 when Actual Cars are 21
Anamoly detected for ImageID: ID_3566f2522, (TP+FP+FN)=0 when Actual Cars are 11
Anamoly detected for ImageID: ID_0e6c355d9, (TP+FP+FN)=0 when Actual Cars are 7
Anamoly detected for ImageID: ID_68fc9ba82, (TP+FP+FN)=0 when Actual Cars are 4
Anamoly detected for ImageID: ID_234456b14, (TP+FP+FN)=0 when Actual Cars are 5
Anamoly detected for ImageID: ID_fd8b62447, (TP+FP+FN)=0 when Actual Cars are 4
Anamoly detected for ImageID: ID_0cf3d5134, (TP+FP+FN)=0 when Actual Cars are 8
Anamoly detected for ImageID: ID_400e4348a, (TP+FP+FN)=0 when Actual Cars are 5
Anamoly detected for ImageID: ID_bb1d991f6, (TP+FP+FN)=0 when Actual Cars are 20
Anamoly detected for ImageID: ID_a792fce8b, (TP+FP+FN)=0 when Actual Cars are 3
Anamoly detected for ImageID: ID_4d238ae90, (TP+FP+FN)=0 when Actual Cars are 19
Anamoly detected for ImageID: ID_fdb989823, (TP+FP+FN)=0 when Actual Cars are 6
Anamoly detected for ImageID: ID_89073c248, (TP+FP+FN)=0 when Actual Cars are 2

"""
pass

# %%
df_anamoly, CSI = analyse_detector_stage(detectorName='yolo',
                                      df_data=df_train.loc[df_train['ImageId'] == "ID_408f58e9f"],
                                      detection_probability=50,extract=False)
display(df_anamoly)
# Out:
# Showing Image, shortly ...
# Anamoly detected for ImageID: ID_408f58e9f, (TP+FP+FN)=0 when Actual Cars are 7
#
# 1/1 Results Predicted. Average CSI so far: 0% (Last 0%)
#           ImageId                                   PredictionString  NumCars  \
# 167  ID_408f58e9f  37 0.130019 0.0131546 -3.02791 7.97754 4.2176 ...        7
#
#      DetectedCars  TP  FP  FN CSI
# 167             0   0   0   0

# %%
#probabs = [5,20,30,50,70,100]
probabs = [5,10,15,20,25,30,35,40,50,60,70,80,90,100]
detectors = ['yolo','resnet']
#df_data = df_train.sample(100)
df_data = df_train.copy()

noFalses = {}
CSIs = {}
FNs = {}
FPs = {}

for detectorName in detectors:
    
    noFalses[detectorName] = []
    CSIs[detectorName] = []
    FNs[detectorName] = []
    FPs[detectorName] = []
    
    for probability in probabs:

        clear_output(wait=True)
        print(f"Checking Detection Probability {probability}% For {detectorName}")

        filename = os.path.join(KERNELS_DIR , "history/"+detectorName+"-"+str(probability)+"-analysis.csv")    
        
        df_prob, CSI = analyse_detector_stage(detectorName=detectorName,df_data=df_data,detection_probability=probability,extract=False)
        CSIs[detectorName].append(CSI*100)

        noFalse = len(df_prob.loc[(df_prob["FP"]==0) & (df_prob["FN"]==0)])
        noFalses[detectorName].append(noFalse)
        
        FP = df_prob["FP"].sum() / (df_prob["FP"].sum()+df_prob["FN"].sum().sum()+df_prob["TP"].sum())
        FN = df_prob["FN"].sum() / (df_prob["FP"].sum()+df_prob["FN"].sum().sum()+df_prob["TP"].sum())
        FPs[detectorName].append(FP)
        FNs[detectorName].append(FN)
        
        df_prob.to_csv(filename)
# Out:
# Anamoly detected for ImageID: ID_8a6e65317, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_337ddc495, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_a381bf4d0, (TP+FP+FN)=0 when Actual Cars are 25
# Anamoly detected for ImageID: ID_7c4a3e0aa, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_8b510fad6, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_679502721, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_f681b269f, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_2803cf7b5, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_89449e126, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_2ad1fc1b3, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_dfbcb7cbf, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_b21f7184c, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_726e547e6, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_f0fca07ab, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_61e1898df, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7f13c4118, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_9fb79f7dd, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_85e8c4d85, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_63ed0ec41, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_5ce45c160, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_99379b1d0, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_2199b4c9f, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_4daffefa0, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_c754c08ad, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_1fa17ae03, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_710229144, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_5116e4436, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_2e52a8a89, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_34121bb7d, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_a6ba74499, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_0a0980d15, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_3fea5815f, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_12e94fdaf, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_472783441, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_7062c0625, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_e487d2c5b, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_68f992ea1, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_9bd2e72b9, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_7602c2067, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_e206c8c53, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_648c471c2, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_f0519289e, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_7b4ad0c54, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_cfd1eec3e, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_7739b8ae1, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_9a83f997d, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_bc0ddb93b, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_9ea9b90a0, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_8cba0a35a, (TP+FP+FN)=0 when Actual Cars are 26
# Anamoly detected for ImageID: ID_5ffc8d5bf, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_b588b63da, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_f1c1cd304, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_8b68340de, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_0d90b3862, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_688d64128, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_f45cea83d, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_044fbdda4, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_e806b720f, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_e50f1212c, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_319a6f249, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_feb8c1352, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_7155f620f, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_c31679c55, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_68d5ab49f, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_dfba4d3ba, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_bfb9600ee, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_f5c2c9a4e, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_b3aa79dad, (TP+FP+FN)=0 when Actual Cars are 23
# Anamoly detected for ImageID: ID_9783bd351, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_e536bac30, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_5d4a30bb1, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_b3aa6f20b, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_224cf5c83, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_72475c36b, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_d75bc1c83, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_2205f49b3, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_2d639a8c9, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_71e0cae6c, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_6aef44806, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_2733fe674, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_882e1dc7f, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_e261ec742, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_9a778d894, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_a2b0aad70, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_3668be834, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_c89179341, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_b38511e47, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_6d93a0eb2, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_3b5b9d6a6, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_5779564c9, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_b8d616497, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_f9a5d1fd4, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_623c31555, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_2fac2e085, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_a4c30e644, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_51d861b9f, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_4e3bc8c4c, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_351825a51, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_a74b40d1b, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_75d5bce55, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_44b5119ef, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_7c80ca14d, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_092664cc7, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_9f3f0a78a, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_1a708607a, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_4b6ee7dbd, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_9d30e6d3e, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_a65b3aab1, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_e002501e4, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_87979afeb, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_3553e493e, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_d327a57f5, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_375c4d72f, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_a9fe81356, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_f0856fc55, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_aa3562f1a, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_c99be8b3c, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_c2a614edc, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_f997df17b, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_1a06df45e, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_d5c507d61, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_c20a626ae, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_fc0ae0432, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_0beb6317a, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_2acf84328, (TP+FP+FN)=0 when Actual Cars are 28
# Anamoly detected for ImageID: ID_94d690cbd, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_e4308de94, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_6448b7be0, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_8c54998d7, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_cba19338b, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_433305e9b, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_439c7efcc, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_2dbfba509, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_66bfef6ac, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_12104686a, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_fe5acc7a0, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_dd1bd7316, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_6642e0508, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_15a8550da, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_e463040d2, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_d9144c0e7, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_798c4c7f8, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_1cfdb9514, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_202b057b5, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_8e794a38e, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_a50a06aa5, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_e630bc65e, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_d9a3448a2, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_b99c98ba9, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_ea4a03a6c, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_c8303bad2, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_b3ad2d375, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_0c2e2ded7, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_689978d47, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_194beaaf9, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_7e4d94572, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_8bdb55c6a, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_d2ec79810, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_a5177d705, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_0b23af8f7, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_587f2c824, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_e02bb6f9f, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_94b4e8e10, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_385ee3357, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_100495023, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_f5b7e8137, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_a9dd3799d, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_408f58e9f, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_a953e427a, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_036388af7, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_5e23bc45b, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_5e19e6af1, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_6bb20ff30, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_be9017c36, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_03a04a0d0, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_9a939e268, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_92b9ea3f4, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_e7fbe939b, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_e48c4723f, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_f20251898, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_54254b736, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_ab673bcde, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_e21e6fa83, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_906f44587, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_c44983aeb, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_62d8d50b8, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_bef31c2aa, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_f848ca93c, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_d952bdca8, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_27f9ecfe1, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_1194e8b72, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_130f54059, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_d9c78255b, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_674d2776b, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_74c97314b, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_b046a2096, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_528f93c29, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_e409c480a, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7fd9b7615, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_5689a0303, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_c24c19fb1, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_409ead651, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_6b6a2fd07, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_6b5879e06, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_d7c3e3eb9, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_c671f55b5, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_40117a32f, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_704e13e8c, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_80b1295e4, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_376d44b52, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_4e5667d73, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_1961516e5, (TP+FP+FN)=0 when Actual Cars are 26
# Anamoly detected for ImageID: ID_be5faedf0, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_beb896c8d, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_959e6f8db, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7339b1c7f, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_a75c42644, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_8d324f009, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_593fe776d, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_2d2fff4cc, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_f822fc646, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_95276c148, (TP+FP+FN)=0 when Actual Cars are 36
# Anamoly detected for ImageID: ID_aed98a12b, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_d921f9e6f, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_3f56adea2, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_e72faeb28, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_4a9c25597, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_10a69aa7c, (TP+FP+FN)=0 when Actual Cars are 23
# Anamoly detected for ImageID: ID_499660405, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_ad4474603, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_f599f6b83, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_61c4ac07f, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_62e5d8e41, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_5bb4d6d29, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_1b6e5350b, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_f31750d23, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_4f54578d0, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_a9bc7f70c, (TP+FP+FN)=0 when Actual Cars are 26
# Anamoly detected for ImageID: ID_6e9fe6af1, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_7fde2df43, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_81f626d61, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_dd5b07fba, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_4ba375b70, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_1e47b9162, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_6b78f8c9b, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_c88b10b51, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_2d37de9f6, (TP+FP+FN)=0 when Actual Cars are 23
# Anamoly detected for ImageID: ID_b3c68dd9b, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_37cfae12d, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_d37ee8494, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_2a20dbdd1, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_4eaa4d11d, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_119fbf1cc, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_6c9d37ccd, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_422d5d2d1, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_34197249f, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_a9f4fd69e, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_5e8739c82, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_8f14af7e3, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_9591b2302, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_09e072c19, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_44b773b50, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_46e404837, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_9710d5c22, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_0ab58a68f, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_91b2a1bb9, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_389ea1ce0, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_bdbf83fd6, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_cf4977d3e, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_878f2dd82, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_f7e0cb875, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_ca6e34a98, (TP+FP+FN)=0 when Actual Cars are 2
# Anamoly detected for ImageID: ID_dbb157ffd, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_df2f7a255, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_fca58bfe9, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_c7d63e9d3, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_fa6a14ba4, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_296fdb6f0, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_361c091a4, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_3a7acc1ad, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_8b6c929ea, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_c29465db5, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_6e2f713ca, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_82d727486, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_9c5cc4a37, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_87f6eb0bf, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_202e5b9e0, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_720487613, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_cb7d03a1c, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_da71d8632, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_c11d71a28, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_eb1b6ecfb, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_44ab7db14, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_28d9ae0eb, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_68e2bdec7, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_111ebee8b, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_de3d48153, (TP+FP+FN)=0 when Actual Cars are 36
# Anamoly detected for ImageID: ID_3f88af6f4, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_2aeb24764, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_8bf184918, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_06bf04a82, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_f5c75d9db, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_8436ab711, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_9db0c69dd, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_cfe862fea, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_7d45af237, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_3ffafe58f, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_df195ccf9, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_c317c8126, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_9d3e927b1, (TP+FP+FN)=0 when Actual Cars are 29
# Anamoly detected for ImageID: ID_e63034e97, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_6d41fb6af, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_7fb05a0e6, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_2f99afb16, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_78e70b9e1, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_3c0575866, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_5b86b687d, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_b047ab162, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_ee2a334fc, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_5f1809778, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_ad84b261f, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_5e8dda242, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_309d86810, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_55a11025e, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7f1b331b9, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_8e21a5979, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_49723e633, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_58104ab68, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_b7ac041e0, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_3e4417447, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_ba123226f, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7f535a8b7, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_a9d36e8db, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_b82d69b05, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_75a0aca2d, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_4b92b6304, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_dcecaf2dc, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_ced4839eb, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_cbf3a674d, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_3b2c71812, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_f45fa2fe7, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_5df96e098, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_e43cd36ca, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_058b3c39d, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_004a3d05a, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_378d17786, (TP+FP+FN)=0 when Actual Cars are 26
# Anamoly detected for ImageID: ID_4ceb38a7f, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_99a1115a5, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_3f5dd0bfb, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_aeba9ec12, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_65048ba35, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_1067a99a3, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_b722b821a, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_33b83e4ab, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_fddcbfc03, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_d4b03f5be, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_a087474e6, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_4e78c2998, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_9006ab316, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_72b22e72b, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_576f20ce1, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_41b66a870, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_7b8967cb0, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_55fe0afa5, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_d83031cf5, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_2663c5921, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_01c850b27, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_819ea83f5, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_df134dd43, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_ffaf41103, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_9ee67eb8f, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_d5319f78c, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_36465e439, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_666ed008e, (TP+FP+FN)=0 when Actual Cars are 30
# Anamoly detected for ImageID: ID_4b76d0f7a, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_bc86d5225, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_08b42e64c, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_cdbb54280, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_087b376a3, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_244b2f79c, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_c5bf3135e, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_4e4ef8d62, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_38b2d431d, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_471c8cd23, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_f08e0fec1, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_929b1b713, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_200721cd7, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_82ba37a6e, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_78505f9a7, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_03642d14a, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_c390063a5, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_8a7424bf2, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_8c5850283, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_825839161, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_759559348, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_fbe10dba8, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_e17ea1f64, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_785427b25, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_995c175fa, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_6e43bd75d, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_e4e5fbd23, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_951b9f1be, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_44d53d804, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_65ae2165d, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_9b3b7804f, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_1879bd6eb, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_563eb2998, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_c4f70463b, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_74418d18e, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_36d0572f4, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_f7e3fd7ef, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_272658681, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_5f6c35f86, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_f67cd0ee0, (TP+FP+FN)=0 when Actual Cars are 25
# Anamoly detected for ImageID: ID_688889724, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_ad3579906, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_056254a62, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_58dfa60ed, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_789fe31ca, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_7b1d51516, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_d7dac6b74, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_66ad0f7e6, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_29b372dd0, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_fc650f918, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_5877dba44, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_556fc2d1d, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_99e9db781, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_e015851f1, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_3d97153ba, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_3e5611107, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_15382f304, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_166c05a91, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_c3416a54a, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_466890b0e, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_59d5052ab, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_a5c2c76a4, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_0a3c2c009, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_28f413fc7, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_060959d63, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_336b738c8, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_ec0e083f4, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_cd37c0a23, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_5d21d8c3f, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_7621ea7f6, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_a3803a364, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_fb196974d, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_1fa31fbc9, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_7f4e67477, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_5859bf927, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_6ca33f63e, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_998d0ae8c, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_460fb532b, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_72283017f, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_726c05fb6, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_a5c1e2b3d, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_8d1c9fad2, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_3eb37c757, (TP+FP+FN)=0 when Actual Cars are 25
# Anamoly detected for ImageID: ID_b19e5b434, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_edd28a56a, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_881a9e9e1, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_a06312dfa, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_f76dece9c, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_3bc16dee0, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_6ee33cb3b, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_f3d205853, (TP+FP+FN)=0 when Actual Cars are 2
# Anamoly detected for ImageID: ID_476df7669, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_1255971a2, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_21536e544, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_81c81d489, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_423927361, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_8abd7063d, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_20773c5a2, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_3909fe800, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_04cdd1006, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_f961ffecc, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_194f2ae8f, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_08c2aa2d9, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_8acb6a645, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_9d1f97fb1, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_b6bdb3ed4, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_3bf3a9ce0, (TP+FP+FN)=0 when Actual Cars are 27
# Anamoly detected for ImageID: ID_0f7c7228a, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_4d6549ef4, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_cb4f8a19d, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_c227d8ef8, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_5cc18fed4, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_ef7e22fb7, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_72f232b24, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_cb1e54316, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_597361377, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_134c5daca, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_98a0325a2, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_63a4e2531, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_b6fd59160, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_d4f37cc62, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_d2108dfe0, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_cb5d35aee, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_65ef8a968, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_0645310c8, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_73f3e0e8e, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_610352cfe, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_69ec33200, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_818c22b77, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_4367ade5a, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_47178980f, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_b839972b5, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_8abec3ee7, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_e007ee87a, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_035dafea5, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_5a30cd477, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_74be9d229, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_0476ab13e, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_19afce0de, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_77e0c92bd, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_317b0b0ce, (TP+FP+FN)=0 when Actual Cars are 31
# Anamoly detected for ImageID: ID_f27e832e3, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_4a637b914, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_afdfe8461, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_382a27acf, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_a5da8c157, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_88f00b564, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_ee5fac28b, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_a1ac97a01, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_1575227e5, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_ba5aaaaa8, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_e696a1e39, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_8628215e3, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_577d1a984, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_b4d6b176b, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_3c2fbeb77, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_ba0126346, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_4587054e3, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_85eae1c19, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_ec7088f95, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_031edc766, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_d5925e047, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_2cf359938, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_964f42166, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_ea2c472a5, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_176b2695a, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_4c89a0157, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_8997a84c4, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_698a7aa2d, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_feff42992, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_3e9920884, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_75143f7b3, (TP+FP+FN)=0 when Actual Cars are 25
# Anamoly detected for ImageID: ID_ca9bb16dc, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_5a9e8c952, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_44b96ce87, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_ea0036630, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_0fbe6e70a, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_0719a8160, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_242767d0a, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_d85f43576, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_3a8fff336, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_86bb8b3d5, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_b5dc26939, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_a4a2578a3, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_b405f63d7, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_7f1cd6e40, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_60565cf6d, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_6e2d28846, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_6f253a738, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_8e352a589, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_7924602f8, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_6067aae64, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_5425a4f39, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_fe262008f, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_53c3fe91a, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_829f04ab3, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_6a8c65399, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_55cdf595c, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_904e98f4a, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_19ec1e093, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_3094be6e6, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_96784d94a, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_1a5a10365, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_77bef5fc8, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_1688bea40, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_b714fe796, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_ad834feee, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_0e6f0cc36, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_dbff229b9, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_a0e6ffd46, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_0aff7961d, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_db88923f5, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_7fdbd9fe5, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_efe6d85b7, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_86badf7ae, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_0ddda042d, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_3f2cc041f, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_c971643a7, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_1e468bfb0, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_657eb589c, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_7de65cabe, (TP+FP+FN)=0 when Actual Cars are 14
# ...
# Anamoly detected for ImageID: ID_4d8bc74dc, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_dcf4928d7, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_b96dca014, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_b488a23cd, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_f45edeb28, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_ab5217907, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_c8877e867, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_3b8d7ba14, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_f7dc44c69, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_332e05c70, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_1e3d90c90, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_456cbcf28, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_dc3a1fc88, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_54c59c47b, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_b10e1ef7f, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_66336cf99, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_483f5669e, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_7c6f5f6ca, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_87ac774ca, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_08f02088e, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_be9277890, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_901fa9e6c, (TP+FP+FN)=0 when Actual Cars are 41
# Anamoly detected for ImageID: ID_d0eb590e9, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_6ac66adfd, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_13b7a0676, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_b9203cbc5, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_88e906b3e, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_cc7290959, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_1809286cd, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_d7a20418b, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_271dbd4dc, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_88806ad07, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_bbe62ed9c, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_b298c78e5, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7942231be, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_1b53f57ae, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_92731f965, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_e404c89ee, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_22d801b6e, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_9848ec679, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_d44bbe32c, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_901117b49, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_db6014c47, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_10478e12b, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_6b58be0f3, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_9ca47e157, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_e1f44d103, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_a5ab220cd, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_7e59a42ae, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_b6ec028fd, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_b90caa725, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_7b9cab32f, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_07ccafb46, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_57969b8e5, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_804d607bf, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_51f3c0953, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_bcfedeae5, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_502ac4f45, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_51b661aea, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_83243edc6, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_95f98c76f, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_bac0c98cd, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_3baf05dab, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_ab3e1ad9f, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_d82a540a4, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_41dc0d196, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_ef8228a54, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_88833c3ee, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_392be605b, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_c2d1b748f, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_40566bc13, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_b1818d324, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_4bdc3aca2, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_07b6fb2a6, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_fd0ca36dd, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_264885789, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_9afedeeea, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_3bb765861, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_1f5310085, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_36db1e0ca, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_71dc7121d, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_f3b1920a5, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_f5d9e450b, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_764774104, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_f388a7b94, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_0f128c40b, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_2358bdd77, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_7134a06e5, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_31024a41a, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_4e73172e3, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_3a5ef288d, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_555862f32, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_920fbfaf1, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_a7ed67ec7, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_76f2e66ce, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_cf8806418, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_2d77faf70, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_7f24eb96e, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_bdf93295c, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_40cf35ac2, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_69dfeed66, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_55fd39826, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7d49a1db9, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_5c27caf6b, (TP+FP+FN)=0 when Actual Cars are 3
# Anamoly detected for ImageID: ID_7cbfd6812, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_8cef10e05, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_6e58b0db4, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_afe579e87, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_983c1e248, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_8da41522e, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_590b5250d, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_c4f92b64e, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_77ca4b051, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_83b367981, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_37f431d28, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_e13896fe3, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_f37fa19a9, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_242468ebf, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_b949232ba, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_2bcb687ef, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_c709928b7, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_f9b2c4de5, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7d9650bed, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_d6e26d4cf, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_9b7c9e798, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_848a03a04, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_e274b8f83, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_e9adaac56, (TP+FP+FN)=0 when Actual Cars are 20
# Anamoly detected for ImageID: ID_bc5effdb6, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_48ecfa2bd, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_c07a4d34e, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_ebc1b2883, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_5953b5675, (TP+FP+FN)=0 when Actual Cars are 26
# Anamoly detected for ImageID: ID_9541f3d9c, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_8dd5eb87f, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_a184560ad, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_4ff31a875, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_5d4ab3dd2, (TP+FP+FN)=0 when Actual Cars are 24
# Anamoly detected for ImageID: ID_41545ccb0, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_135e087f5, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_fa319940a, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_b831989ce, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_ac41002c9, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_32e5bd910, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_becda64dd, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_0db53ef6d, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_2a4241355, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_d40ea33fb, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_220644160, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_7cc8ed862, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_24a0c6ef3, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_73f9e548e, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_7836560d4, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_9b0d216b3, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_9eef06273, (TP+FP+FN)=0 when Actual Cars are 25
# Anamoly detected for ImageID: ID_b6e911d41, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_4b29ca144, (TP+FP+FN)=0 when Actual Cars are 6
# Anamoly detected for ImageID: ID_60c4f818f, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_2e808c4f0, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_8839049d3, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_0119bb6f9, (TP+FP+FN)=0 when Actual Cars are 19
# Anamoly detected for ImageID: ID_c16c679f5, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_a79f4ddf9, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_7b81dab6e, (TP+FP+FN)=0 when Actual Cars are 23
# Anamoly detected for ImageID: ID_7bec261bc, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_f3a70f246, (TP+FP+FN)=0 when Actual Cars are 11
# Anamoly detected for ImageID: ID_787885b17, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_dc71fa02b, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_c315ecda5, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_308740c55, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_5c7ce73cc, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_84c029c6e, (TP+FP+FN)=0 when Actual Cars are 14
# Anamoly detected for ImageID: ID_3c8c6bdf1, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_6b2b601c7, (TP+FP+FN)=0 when Actual Cars are 4
# Anamoly detected for ImageID: ID_0449ab8fd, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_3e29faeb0, (TP+FP+FN)=0 when Actual Cars are 13
# Anamoly detected for ImageID: ID_bf1a2af2b, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_d69c0e50d, (TP+FP+FN)=0 when Actual Cars are 5
# Anamoly detected for ImageID: ID_6fa356a29, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_240918ae7, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_c6d204ae9, (TP+FP+FN)=0 when Actual Cars are 22
# Anamoly detected for ImageID: ID_c1edc9dea, (TP+FP+FN)=0 when Actual Cars are 21
# Anamoly detected for ImageID: ID_9828e3378, (TP+FP+FN)=0 when Actual Cars are 15
# Anamoly detected for ImageID: ID_374f09822, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_8eafe31e3, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_6bcfbe419, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_3374e33b6, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_5d8199999, (TP+FP+FN)=0 when Actual Cars are 2
# Anamoly detected for ImageID: ID_7c861e895, (TP+FP+FN)=0 when Actual Cars are 9
# Anamoly detected for ImageID: ID_a0d2d33a3, (TP+FP+FN)=0 when Actual Cars are 18
# Anamoly detected for ImageID: ID_5859c928f, (TP+FP+FN)=0 when Actual Cars are 17
# Anamoly detected for ImageID: ID_f865e2a0d, (TP+FP+FN)=0 when Actual Cars are 10
# Anamoly detected for ImageID: ID_de17ab626, (TP+FP+FN)=0 when Actual Cars are 8
# Anamoly detected for ImageID: ID_5a669e211, (TP+FP+FN)=0 when Actual Cars are 12
# Anamoly detected for ImageID: ID_aa6ffba0a, (TP+FP+FN)=0 when Actual Cars are 16
# Anamoly detected for ImageID: ID_29454123f, (TP+FP+FN)=0 when Actual Cars are 7
# Anamoly detected for ImageID: ID_2dee4d6e6, (TP+FP+FN)=0 when Actual Cars are 10
#
# 4262/4262 Results Predicted. Average CSI so far: 0% (Last 0%)

# %%
# Generate Detection Analysis Plots

"""
   -                solid line style
   --               dashed line style
   -.               dash-dot line style
   :                dotted line style
   .                point marker
   ,                pixel marker
   o                circle marker
   v                triangle_down marker
   ^                triangle_up marker
   <                triangle_left marker
   >                triangle_right marker
   s                square marker
   p                pentagon marker
   *                star marker
"""

linestyles = ['-','--','-.',':']
markerstyles = ['*','s','v','o','<','p','^','.','>']

# CSI

fig, ax = plt.subplots()

for count,detectorName in enumerate(detectors):
    ax.plot(probabs, CSIs[detectorName], label=detectorName, 
            linestyle=linestyles[count%len(linestyles)], marker=markerstyles[count%len(markerstyles)])
ax.set(xlabel='Detection Probability (%)', ylabel='Critical Success Index (%)',
       title=f"Detection analysis on dataset of {len(df_data)} rows out of {len(df_train)}")
ax.grid()
plt.legend(loc='lower left')
filename = os.path.join(ANALYSIS_DIR, f"detector_{len(df_data)}-rows_CSI-analysis.png")   
fig.savefig(filename)
plt.show()


# noFalse

fig, ax = plt.subplots()

for count,detectorName in enumerate(detectors):
    ax.plot(probabs, noFalses[detectorName], label=detectorName, 
            linestyle=linestyles[count%len(linestyles)], marker=markerstyles[count%len(markerstyles)])
ax.set(xlabel='Detection Probability (%)', ylabel='No False Count (#)',
       title=f"Detection analysis on dataset of {len(df_data)} rows out of {len(df_train)}")
ax.grid()
plt.legend(loc='lower right')
filename = os.path.join(ANALYSIS_DIR, f"detector_{len(df_data)}-rows_noFalse-analysis.png")   
fig.savefig(filename)
plt.show()


# FP and FN

fig, ax = plt.subplots()

count = 0
for detectorName in detectors:
    ax.plot(probabs, FNs[detectorName], label=detectorName+" FN", 
            linestyle=linestyles[count%len(linestyles)], marker=markerstyles[count%len(markerstyles)])
    count+=1
    ax.plot(probabs, FPs[detectorName], label=detectorName+" FP", 
            linestyle=linestyles[(count)%len(linestyles)], marker=markerstyles[(count)%len(markerstyles)])
    count+=1
    
ax.set(xlabel='Detection Probability (%)', ylabel='False Counts out of Total (%)',
       title=f"Detection analysis on dataset of {len(df_data)} rows out of {len(df_train)}")
ax.grid()
plt.legend(loc='upper right')
plt.yscale('linear')
filename = os.path.join(ANALYSIS_DIR, f"detector_{len(df_data)}-rows_FP-FN-analysis.png")   
fig.savefig(filename)
plt.show()

# %%
# Generate Actual Extractions based on best performing detector
# Found YOLO with 30% DPT

df_yolo, CSI = analyse_detector_stage(detectorName='yolo',df_data=df_train.head(10),detection_probability=30,extract=True)
df_yolo
